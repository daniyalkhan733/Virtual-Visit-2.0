# %% [markdown]
# # Daniyal Khan || 221A061 || 19

# %%
# Daniyal Khan || 221A061

# !pip install yt-dlp -q


import yt_dlp
import random
from IPython.display import Image, display
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 44.1 MB/s eta 0:00:00

# %%
# Daniyal Khan || 221A061


def generate_colab_promotion(video_url):
    # 2. Extract Metadata (Title & Thumbnail) without API Key
    ydl_opts = {'quiet': True, 'no_warnings': True}
    try:
        print("🔄 Fetching creative assets from YouTube...")
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info = ydl.extract_info(video_url, download=False)
            video_title = info.get('title', 'our latest video Update')
            thumbnail_url = info.get('thumbnail')
    except Exception as e:
        print(f"❌ Error fetching data: {e}")
        return

# %%
# Daniyal Khan || 221A061
   # Updated Video Metadata for 2026
video_title = "Web Development Roadmap 2026 (No BS Guide!)"

hooks = [
    f"🚀 Exciting news! We just dropped a new video: {video_title}",
    f"🔥 Want to scale your career in the AI era? Check out: {video_title}",
    f"✨ Exclusive Insight: Everything you need to know about becoming a 10X Developer in 2026",
    f"💡 Knowledge is power. Watch our deep dive into {video_title}",
    f"🌟 Stop scrolling! You need to see our take on {video_title}"
]

body_texts = [
    "Our team has put together the ultimate guide to help you navigate the 2026 tech landscape, where AI doesn't replace you—it makes you 10x more powerful.",
    "Learn the exact roadmap—from HTML/CSS to Next.js and AI-powered IDs—that we use to stay ahead of the competition in a $2 trillion economy.",
    "We've simplified complex concepts like SQL vs. NoSQL and Server Actions so you can build scalable, profit-ready applications immediately.",
    "Join thousands of developers who are moving beyond 'code typing' to become 'AI Pilots' using these 2026-ready industry insights."
]

ctas = [
    "▶️ Watch the full breakdown here: https://www.youtube.com/watch?v=-4e3ewcTupM",
    "🔗 Click the link to view the 2026 Guide on YouTube: https://www.youtube.com/watch?v=-4e3ewcTupM",
    "👇 Don't miss out on the 12-month action plan, watch now: https://www.youtube.com/watch?v=-4e3ewcTupM",
    "📢 See the full story and roadmap here: https://www.youtube.com/watch?v=-4e3ewcTupM"
]

# %%
# Daniyal Khan || 221A061
selected_hook = random.choice(hooks)
selected_body = random.choice(body_texts)
selected_cta = random.choice(ctas)
video_url = "https://www.youtube.com/watch?v=-4e3ewcTupM"

# %%
# Daniyal Khan || 221A061

target_url = "https://www.youtube.com/watch?v=-4e3ewcTupM"
generate_colab_promotion(target_url)
# Out:
# 🔄 Fetching creative assets from YouTube...

# %%
# Daniyal Khan || 221A061

from IPython.display import display, Image, clear_output, HTML
import ipywidgets as widgets
import random

# --- Data ---
video_title = "Web Development Roadmap 2026 (No BS Guide!)"
video_url = "https://www.youtube.com/watch?v=-4e3ewcTupM"
thumbnail_url = "https://i.ytimg.com/vi/-4e3ewcTupM/maxresdefault.jpg"

# --- Interactive Styling & Logic ---
def generate_styled_post(b=None):
    clear_output(wait=True)

    h = random.choice(hooks)
    b_text = random.choice(body_texts)
    c = random.choice(ctas)

    html_content = f"""
    <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
                max-width: 600px; border: 1px solid #e1e4e8; border-radius: 15px;
                overflow: hidden; box-shadow: 0px 10px 25px rgba(0,0,0,0.1); background-color: white;">

        <div style="background: linear-gradient(135deg, #6e8efb, #a777e3); padding: 20px; color: white; text-align: center;">
            <h2 style="margin: 0; font-size: 1.5em;">📱 Social Media Preview</h2>
            <p style="margin: 5px 0 0 0; opacity: 0.8; font-size: 0.9em;">AI-Generated for CodeWithHarry</p>
        </div>

        <div style="padding: 25px; line-height: 1.6; color: #333;">
            <p style="font-size: 1.1em; margin-bottom: 15px;">{h}</p>
            <p style="background: #f8f9fa; padding: 15px; border-left: 5px solid #6e8efb; border-radius: 5px; font-style: italic;">
                {b_text}
            </p>
            <p style="margin-top: 20px; font-size: 1.05em;">{c}</p>
        </div>

        <div style="padding: 0 25px 25px 25px; text-align: center;">
            <img src="{thumbnail_url}" style="width: 100%; border-radius: 10px; box-shadow: 0 4px 8px rgba(0,0,0,0.15);">
        </div>

        <div style="background: #f1f3f5; padding: 10px; text-align: center; font-size: 0.8em; color: #666;">
            Ready to post? Just copy the text and upload the image!
        </div>
    </div>
    """
    display(HTML(html_content))
    display(button)

# Styled Shuffle Button
button = widgets.Button(
    description="✨ REGENERATE CREATIVE ✨",
    layout=widgets.Layout(width='600px', height='50px', margin='20px 0 0 0')
)
button.style.button_color = '#6e8efb'
button.style.font_weight = 'bold'

button.on_click(generate_styled_post)

# Initial Display
generate_styled_post()
# Out:
#     <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#                 max-width: 600px; border: 1px solid #e1e4e8; border-radius: 15px;
#                 overflow: hidden; box-shadow: 0px 10px 25px rgba(0,0,0,0.1); background-color: white;">
#
#         <div style="background: linear-gradient(135deg, #6e8efb, #a777e3); padding: 20px; color: white; text-align: center;">
#             <h2 style="margin: 0; font-size: 1.5em;">📱 Social Media Preview</h2>
#             <p style="margin: 5px 0 0 0; opacity: 0.8; font-size: 0.9em;">AI-Generated for CodeWithHarry</p>
#         </div>
#
#         <div style="padding: 25px; line-height: 1.6; color: #333;">
#             <p style="font-size: 1.1em; margin-bottom: 15px;">💡 Knowledge is power. Watch our deep dive into <b>Web Development Roadmap 2026 (No BS Guide!)</b></p>
#             <p style="background: #f8f9fa; padding: 15px; border-left: 5px solid #6e8efb; border-radius: 5px; font-style: italic;">
# ...
