# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
y = [5,20,25,40,65,80,100]

# %%
plt.plot(y);

# %%
x= [2,12,22,36,40,54,62,72,80,90]

y = [5,20,25,35,40,50,65,80,95,100]

# %%
plt.plot(x,y,color='red');
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Line Plot')
plt.legend(['Line 1'])
plt.figsize=10,10

# %%
plt.scatter(x,y);

# %%
plt.plot(x,y,'o');

# %%
plt.plot(x,y,color='red',linestyle='--',marker='o');
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Line Plot')
plt.legend(['Line 1'])
plt.figsize=10,10

# %%
plt.plot(x,y,'ko--');
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Line Plot')
plt.legend(['Line 1'])
plt.figsize=10,10

# %%
import numpy as np
#y=x^2 in the range of -10 to 10
y = np.linspace(-10,10,100)
x=y**2

plt.plot(x,y,'g*--', markersize=12, markeredgecolor='red',
         markerfacecolor='red', linewidth=2, alpha=0.5, markevery=6)
plt.xlabel('x values')
plt.ylabel('y values')
# Out:
# Text(0, 0.5, 'y values')

# %%
plt.figure(figsize=(6,6))

plt.pie([4,1,6,9,16],explode=[0,0.2,0,0,0], labels=['Cherry Pie','Apple Pie','Rhubarb Pie','Bluberry Pie','Orange Pie'],
        colors=['red','green', 'blue', 'orange', 'purple'], startangle=45, textprops={'fontsize':12})
# Out:
# ([<matplotlib.patches.Wedge at 0x78cc54849550>,
#   <matplotlib.patches.Wedge at 0x78cc5733b6d0>,
#   <matplotlib.patches.Wedge at 0x78cc56a031d0>,
#   <matplotlib.patches.Wedge at 0x78cc56a2bf10>,
#   <matplotlib.patches.Wedge at 0x78cc572ebed0>],
#  [Text(0.4648800762494693, 0.9969385711799337, 'Cherry Pie'),
#   Text(-5.682480700242114e-08, 1.2999999999999987, 'Apple Pie'),
#   Text(-0.630934331618732, 0.9010670725228085, 'Rhubarb Pie'),
#   Text(-1.0336617865206896, -0.37622242236057196, 'Bluberry Pie'),
#   Text(0.9010674360574423, -0.6309338124374595, 'Orange Pie')])

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
from matplotlib.lines import Line2D
from IPython.core.display import display

#create a new figure
fig = Figure(figsize=(10,8))

#attach a canvas to the figure
FigureCanvas(fig)

#add a subplot (i.e. an Axes object)
ax = fig.add_subplot(1,1,1)

#create some lines and add them to the plot

#intercepts and slopes for the three data series
lines = [(2,-0.8),(1,0.3),(-1,1.2)]

#other visual parameters that vary by line
colors = ['navy', 'g', 'k']
markers =['*', 'o' ,'v']
labels = ['blue','green', 'black']


#loop over data series, construct Line2D for each one
#and add it to the subplot

for i in range(3):
  intercept, slope = lines[i]
  #create some data
  x = np.random.normal(size=30)
  y = x * slope + np.random.normal(intercept, 0.6, size=30)
  # make the line
  line = Line2D(x,y, marker=markers[i], linestyle='',color=colors[i],
                markersize=12, fillstyle='none', markeredgewidth=1.5,
                label=labels[i])
  # add line to plot
  ax.add_line(line)

#set white background
ax.set_facecolor('white')

#set up grid lines
ax.grid(which='both')
major_ticks = np.arange(-10,10,1)
minor_ticks = np.arange(-10,10,0.2)
ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticks)
ax.set_yticks(minor_ticks, minor=True)
ax.grid(which='minor', alpha=0.4, color='grey')
ax.grid(which='major', alpha=0.9)

#set x and y-axis limits
ax.set(xlim=(-3,3), ylim=(-4,4))

ax.set_title('Distribution of colored shapes', fontsize=22)
ax.set_xlabel('x', fontsize=18, labelpad=10)
ax.set_ylabel('y', fontsize=18)

ax.legend(loc='lower right', fontsize=14, framealpha=0.5, edgecolor='k')

display(fig)

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
from matplotlib.lines import Line2D
from IPython.core.display import display

#create a new figure
fig = Figure(figsize=(10,8))

#attach a canvas to the figure
FigureCanvas(fig)

#add a subplot (i.e. an Axes object)
ax = fig.add_subplot(1,1,1)

#create some lines and add them to the plot

#intercepts and slopes for the three data series
lines = [(2,-0.8),(1,0.3),(-1,1.2)]

#other visual parameters that vary by line
colors = ['navy', 'g', 'k']
markers =['*', 'o' ,'v']
labels = ['blue','green', 'black']


#loop over data series, construct Line2D for each one
#and add it to the subplot

for i in range(3):
  intercept, slope = lines[i]
  #create some data
  x = np.random.normal(size=30)
  y = x * slope
  # make the line
  line = Line2D(x,y, marker=markers[i], linestyle='',color=colors[i],
                markersize=12, fillstyle='none', markeredgewidth=1.5,
                label=labels[i])
  # add line to plot
  ax.add_line(line)

#set white background
ax.set_facecolor('white')

#set up grid lines
ax.grid(which='both')
major_ticks = np.arange(-10,10,1)
minor_ticks = np.arange(-10,10,0.2)
ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticks)
ax.set_yticks(minor_ticks, minor=True)
ax.grid(which='minor', alpha=0.4, color='grey')
ax.grid(which='major', alpha=0.9)

#set x and y-axis limits
ax.set(xlim=(-3,3), ylim=(-4,4))

ax.set_title('Distribution of colored shapes', fontsize=22)
ax.set_xlabel('x', fontsize=18, labelpad=10)
ax.set_ylabel('y', fontsize=18)

ax.legend(loc='lower right', fontsize=14, framealpha=0.5, edgecolor='k')

display(fig)

# %%
x = np.linspace(-10,10,100)
x = np.linspace(-10,10,100)
y = x**2

plt.plot(x,y,'g*--', markersize=16, markeredgecolor='black',
         markerfacecolor='blue', linewidth=3, alpha=0.8, markevery=10)



plt.gcf().set_size_inches((8,4))

plt.title('Matplotlib impressions', fontsize=20)
plt.xlabel('Time spent working in matplotlib', fontsize=16, labelpad=15)
plt.ylabel('Desire to work in matplotlib', fontsize=16, labelpad=15)

plt.xticks([-9.5,10], ['newbie', 'master'], fontsize=12)
plt.yticks([18,110], ['fast', 'slow'],rotation=90,ha='right', fontsize=12)

plt.gca().tick_params(axis=u'both', which=u'both', length=0)

plt.annotate("a lucky blue star!", (x[10] + 0.5,y[10]), xytext=(x[20] + 3,y[20] + 40),
             arrowprops=dict(facecolor='black',width=1), fontsize=14)
plt.annotate("a lucky blue star!", (x[49] + 0.5,y[49]), xytext=(x[35] + 3,y[35] + 40),
             arrowprops=dict(facecolor='black',width=1), fontsize=14)
# Out:
# Text(0.07070707070707094, 48.58075706560555, 'a lucky blue star!')

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(4,4))
img = mpimg.imread('/content/flower.jpg')
plt.imshow(img)
plt.show()

# %%
#importing iris dataset
import seaborn as sns
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
fig, axes = plt.subplots(4, 3, figsize=(6,6))

species = ['setosa', 'versicolor', 'virginica']  # Corrected typo
attrs = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

for i in range(3):
  sp = species[i]
  sp_data = iris.query('species == @sp')
  axes[0, i].set_title(sp, fontsize='16')
  for j in range(4):
     attr = attrs[j]
     values = sp_data[attr]
     axes[j, i].hist(values)

     if i == 0:
       axes[j, i].set_ylabel(attr, fontsize=12)

plt.tight_layout()
plt.show()

# %%
iris.boxplot(by='species', figsize=(8,8), layout=(2,2));
